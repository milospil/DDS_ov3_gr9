# %%
Problem statement:
context:
Smoking and alcohol consumption are major lifestyle factors affecting health. 
Excessive smoking and drinking are linked to cardiovascular disease, liver damage, and metabolic disorders. 
Early detection of individuals who smoke, drink, or both, based on biometric and clinical data, can help target interventions 
and preventive healthcare measures.

Problem: Given a set of demographic, clinical, and biochemical measurements from health screenings
    (blood pressure, blood sugar, cholesterol, liver enzymes, kidney markers, BMI, age, sex, etc.), 
    we want to identify individuals’ smoking and drinking behaviors. 
    Detecting these behaviors from routine health data can support health professionals in preventive care 
    and risk assessment without relying on self-reported questionnaires, which are often biased.

ML-problem statement:


- connect this machine learning problem to the real world scenario.
